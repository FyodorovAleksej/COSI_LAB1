# %%
import transfer

print("Input F_MAX (175)")
F_MAX = int(input())
print("Input G_MAX (125)")
G_MAX = int(input())

G_MIN1 = 0
F_MAX1 = 255
F_MIN1 = 255 - G_MAX

G_MAX2 = 255
F_MIN2 = 0
G_MIN2 = 255 - F_MAX
# Out:
# Input F_MAX (175)
# 175
# Input G_MAX (125)
# 125

# %% [markdown]
# # Original
# ![title](./image1.jpg "original")

# %%
transfer.histogram("./image1.jpg", "origin")

# %% [markdown]
# # Original histograms
# ## red original
# ![title](./origin/histRed.png "origin red")
# ## green original
# ![title](./origin/histGreen.png "origin green")
# ## blue original
# ![title](./origin/histBlue.png "origin blue")

# %%
transfer.toGrayScale("./image1.jpg", "ans.jpg")

# %% [markdown]
# # GRAY
# ![title](./ans.jpg "gray")

# %%
transfer.preparationLess("./image1.jpg", "less.jpg", F_MIN1, G_MIN1, G_MAX)

# %% [markdown]
# # LESS
# ![title](./less.jpg "less")

# %%
transfer.preparationMore("./image1.jpg", "more.jpg", F_MAX, G_MIN2, G_MAX2)

# %% [markdown]
# # MORE
# ![title](./more.jpg "more")

# %%
transfer.previsFilter("./image1.jpg", "filt.jpg")

# %% [markdown]
# # FILTER
# ![title](./filt.jpg "filter")

# %%
transfer.previsFilter("./ans.jpg", "filtAns.jpg")

# %% [markdown]
# # FILTER GRAY
# ![title](./filtAns.jpg "filter gray")

# %%
transfer.histogram("./less.jpg", "less")
transfer.histogram("./more.jpg", "more")
transfer.histogram("./filt.jpg", "filt")
transfer.histogram("./filtAns.jpg", "filtAns")

# %% [markdown]
# # Less histograms
# ## red less
# ![title](./less/histRed.png "origin red")
# ## green less
# ![title](./less/histGreen.png "origin green")
# ## blue less
# ![title](./less/histBlue.png "origin blue")
#
#
# # More histograms
# ## red more
# ![title](./more/histRed.png "origin red")
# ## green more
# ![title](./more/histGreen.png "origin green")
# ## blue more
# ![title](./more/histBlue.png "origin blue")
#
#
# # Filt histograms
# ## red filt
# ![title](./filt/histRed.png "origin red")
# ## green filt
# ![title](./filt/histGreen.png "origin green")
# ## blue filt
# ![title](./filt/histBlue.png "origin blue")
#
#
# # Filt gray histograms
# ## red filt
# ![title](./filtAns/histRed.png "origin red")
# ## green filt
# ![title](./filtAns/histGreen.png "origin green")
# ## blue filt
# ![title](./filtAns/histBlue.png "origin blue")
